# %% [markdown]
# to use install all
# opencv-python-headless==4.7.0.72
# pydub==0.25.1
# streamlit_webrtc==0.44.7
# twilio~=8.1.0
# pip install av==9.1.0

# %% [markdown]
# working templates: face_mesh_app.py, app.py, C:\Users\igorv\Desktop\Proffessionals\stream.py

# %%
import tensorflow as tf

print("Num of GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num of GPUs Available:  0

# %%
# !streamlit run 1.py
# Out:
# ^C

# %%
# !streamlit run fresh_view/Demos/face_mesh_app.py
# Out:
# ^C

# %% [markdown]
# Проект "Нанесение лицевой сетки" может иметь несколько потенциальных применений и быть полезным в различных областях. Вот несколько возможных способов, как такой проект может быть полезен:
#
# Безопасность и идентификация и биометрия: Технология лицевой сетки может быть интегрирована в системы безопасности для биометрической аутентификации, контроля доступа и видеонаблюдения. Она предлагает неинвазивный и эффективный метод идентификации лиц на основе их уникальных черт лица.
#
# Медицинская диагностика:  Она также может использоваться для консультаций в телемедицине, позволяя врачам проводить обследование пациентов удаленно, поддерживая визуальный контакт. В медицинской сфере нанесение лицевой сетки может использоваться для диагностики различных заболеваний, аномалий или состояний. Например, это может быть полезно в дерматологии для анализа состояния кожи или в офтальмологии для диагностики глазных заболеваний, реконструктивной хирургии лица.
#
# Образование: Технология лицевой сетки может улучшить образовательный контент, предоставляя интерактивные уроки по анатомии, физиологии и выражению лиц. Она также может использоваться в тренировочных симуляторах для профессий, где выражения лица играют важную роль, таких как актерское мастерство, публичное выступление и обслуживание клиентов.
#
# Приложения дополненной реальности (AR): Технология лицевой сетки может использоваться в AR-приложениях для наложения цифрового контента на лицо человека в реальном времени. Это может улучшить пользовательский опыт в играх, развлекательных приложениях, виртуальных примерках макияжа и виртуальных примерочных, интерактивных игр. Это может включать в себя возможность взаимодействия с игровыми персонажами на основе выражений лица или создания персонализированных игровых персонажей на основе лиц пользователей.

# %% [markdown]
# Виртуальная коммуникация: Она может облегчить виртуальную коммуникацию, добавляя визуальные улучшения к видеозвонкам и видеоконференциям. Это может включать применение фильтров, виртуальных фонов или цифровых аксессуаров прямо на лицо пользователя в реальном времени.
#
#
# Анимация лиц и распознавание эмоций: Технологию лицевой сетки можно использовать в анимационных студиях для создания реалистичной анимации лиц для фильмов, телешоу и видеоигр. Кроме того, она может помочь в системах распознавания эмоций, отслеживая выражения лица и жесты для различных приложений, включая маркетинговые исследования, тестирование пользовательского опыта и мониторинг психического здоровья.
#
# Маркетинг и аналитика: Проект "Нанесение лицевой сетки" может быть полезен для анализа поведения потребителей и реакций на маркетинговые материалы. Это может включать в себя анализ выражений лица при просмотре рекламных роликов или изучение реакций на продукты в магазинах.
#
#
#
# Разработка игр и развлечений: В игровой индустрии технологии распознавания лиц могут использоваться для создания интерактивных игр или развлекательных приложений. Это может включать в себя возможность взаимодействия с игровыми персонажами на основе выражений лица или создания персонализированных игровых персонажей на основе лиц пользователей.
#
# Доступность и помощные технологии: Для людей с ограниченными возможностями технология лицевой сетки может быть адаптирована для помощи устройств, позволяя управлять устройствами без использования рук через жесты и выражения лица. Это может улучшить доступность для людей с ограниченной подвижностью или ловкостью.
